# %%
# Step 1: Import necessary libraries
import pandas as pd
import numpy as np
import xarray as xr
import os

# %%
# Step 2: Loading Excel file
df = pd.read_excel(r"E:\Climpact\BMD\Dhaka.xlsx")

# Step 3: Preview the data (optional)
df.head()
# Out:
#    Year  Month  Day  Rainfall  Tmin  Tmax
# 0  1980      1    1         0  11.8  24.7
# 1  1980      1    2         0  13.4  21.1
# 2  1980      1    3         3  14.0  22.8
# 3  1980      1    4         0  13.9  25.0
# 4  1980      1    5         0  13.4  25.6

# %%
# Step 4: Save in CLIMPACT2-compatible .txt format

df.to_csv("Dhaka_CLIMPACT2_format.txt", sep="\t", index=False, float_format="%.1f",header=False)

print(f"Saved to {'Dhaka_CLIMPACT2_format.txt'}")
# Out:
# Saved to Dhaka_CLIMPACT2_format.txt
